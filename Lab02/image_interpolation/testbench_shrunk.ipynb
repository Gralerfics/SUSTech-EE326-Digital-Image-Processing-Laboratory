# %%
import matplotlib.pyplot as plt
import time

import utils
import interpolation

img_raw = utils.loadGrayscaleAsNumpy("res/rice.tif")
scalar = 0.7

# %% [markdown]
# # Nearest
# ### v0

# %%
start = time.time()
img = interpolation.nearest_v0(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()
# Out:
# Time Cost: 0.20499849319458008 s.

# %% [markdown]
# ### v1

# %%
start = time.time()
img = interpolation.nearest_v1(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()
# Out:
# Time Cost: 0.017019987106323242 s.

# %% [markdown]
# ### latest

# %%
start = time.time()
img = interpolation.nearest(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()

utils.saveGrayscale(img, "output/shrunk_nearest_12112907.tif")
# Out:
# Time Cost: 0.0009980201721191406 s.

# %% [markdown]
# # Bilinear
# ### v0

# %%
start = time.time()
img = interpolation.bilinear_v0(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()
# Out:
# Time Cost: 0.7350506782531738 s.

# %% [markdown]
# ### v1

# %%
start = time.time()
img = interpolation.bilinear_v1(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()
# Out:
# Time Cost: 0.08500027656555176 s.

# %% [markdown]
# ### latest

# %%
start = time.time()
img = interpolation.bilinear(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()

utils.saveGrayscale(img, "output/shrunk_bilinear_12112907.tif")
# Out:
# Time Cost: 0.003457784652709961 s.

# %% [markdown]
# ### scipy.interpolate.interp2d

# %%
start = time.time()
img = interpolation.bilinear_scipy(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()

utils.saveGrayscale(img, "output/shrunk_bilinear_scipy.tif")
# Out:
# Time Cost: 0.00503849983215332 s.

# %% [markdown]
# # Bicubic
# ### latest

# %%
start = time.time()
img = interpolation.bicubic(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()

utils.saveGrayscale(img, "output/shrunk_bicubic_12112907.tif")
# Out:
# Time Cost: 0.05200052261352539 s.

# %% [markdown]
# ### scipy.interpolate.interp2d

# %%
start = time.time()
img = interpolation.bicubic_scipy(img_raw, (round(256 * scalar), round(256 * scalar)))
print("Time Cost: {} s.".format(time.time() - start))

plt.imshow(img, cmap="gray")
plt.show()

utils.saveGrayscale(img, "output/shrunk_bicubic_scipy.tif")
# Out:
# Time Cost: 0.0060002803802490234 s.
